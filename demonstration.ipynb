# %% [markdown]
# # Demonstration of kimanalysis
#
# This Notebook serves as basic demonstration/documentation for the kimanalysis package.  The kimanalysis package is designed to access data stored on the openKIM database by querying the published openKIM webpages.
#
# __Version date__: 2018-08-06.

# %% [markdown]
# ## Required packages
#
# The kimanalysis package requires the following Python packages that are not part of the standard library:
#
# - [requests](http://docs.python-requests.org/en/master/)
#
# - [pandas](https://pandas.pydata.org/)
#
# - [edn_format](https://github.com/swaroopch/edn_format)

# %% [markdown]
# __Library imports__

# %%
import kimanalysis
import kimanalysis.unitconvert as uc
uc.reset_units(length = 'angstrom', mass = 'amu', energy='eV', charge='e')

# %%
import numpy as np

# %%
'-'.join(np.array('asdf-tre-asf-paoa-pamf'.split('-'))[[0,1,2,4]])
# Out:
# 'asdf-tre-asf-pamf'

# %%
result = 'TE_320860761056_001-and-MO_800509458712_001-1525993487-tr'
print(kimanalysis.shortcode(result))
print(kimanalysis.shortid(result))
print(kimanalysis.extendedid(result))
# Out:
# TE_320860761056_001-and-MO_800509458712_001-1525993487-tr
# TE_320860761056_001-and-MO_800509458712_001-1525993487-tr
# TE_320860761056_001-and-MO_800509458712_001-1525993487-tr

# %%
kimanalysis.listfiles(result)
# Out:
# ['kim.log',
#  'kimspec.edn',
#  'lammps.dump',
#  'lammps.in',
#  'lammps.log',
#  'pipeline.stderr',
#  'pipeline.stdin',
#  'pipeline.stdin.info',
#  'pipeline.stdout',
#  'pipelinespec.edn',
#  'results.edn']

# %%
kimanalysis.getfile(result, 'results.edn', contentformat='edn')
# Out:
# {'short-name': {'source-value': ['bcc']}, 'a': {'si-unit': 'm', 'source-unit': 'angstrom', 'si-value': [4.72122e-10, 4.4048800000000003e-10, 4.2088260000000005e-10, 4.066381e-10, 3.954437e-10, 3.862208e-10, 3.783779e-10, 3.7155520000000003e-10, 3.655176e-10, 3.601029e-10, 3.551946e-10, 3.507059e-10, 3.4657070000000004e-10, 3.4273750000000003e-10, 3.39165e-10, 3.3582000000000004e-10, 3.326754e-10, 3.297084e-10, 3.269001e-10, 3.242343e-10, 3.216973e-10, 3.1927720000000005e-10, 3.169637e-10, 3.147477e-10, 3.132392e-10, 3.116515e-10, 3.0997590000000004e-10, 3.0820210000000003e-10, 3.063179e-10, 3.0430860000000003e-10, 3.0215630000000003e-10, 2.998393e-10], 'source-value': [4.72122, 4.40488, 4.208826, 4.066381, 3.954437, 3.862208, 3.783779, 3.715552, 3.655176, 3.601029, 3.551946, 3.507059, 3.465707, 3.427375, 3.39165, 3.3582, 3.326754, 3.297084, 3.269001, 3.242343, 3.216973, 3.192772, 3.169637, 3.147477, 3.132392, 3.116515, 3.099759, 3.082021, 3.063179, 3.043086, 3.021563, 2.998393]}, 'property-id': 'tag:staff@noreply.openkim.org,2014-04-15:property/cohesive-energy-relation-cubic-crystal', 'cohesive-potential-energy': {'si-unit': 'kg m^2 / s^2', 'source-unit': 'eV', 'si-value': [2.335508881906368e-19, 2.8881957290175363e-19, 3.1925291781384964e-19, 3.4850866290965763e-19, 3.768095107394688e-19, 4.021815797064576e-19, 4.256054019025536e-19, 4.445206990877185e-19, 4.598951859409152e-19, 4.727526533228352e-19, 4.834119343810176e-19, 4.919483314166401e-19, 4.9873675375896965e-19, 5.042658652773505e-19, 5.089522318931904e-19, 5.128583384947009e-19, 5.163110291125248e-19, 5.198630546808385e-19, 5.230113317407105e-19, 5.255507816846785e-19, 5.274381457439808e-19, 5.287327044535872e-19, 5.295546210600576e-19, 5.2984301285180165e-19, 5.296924082494464e-19, 5.291829160840321e-19, 5.282039861687233e-19, 5.266098204310273e-19, 5.242225772660352e-19, 5.208003280040064e-19, 5.160226373207808e-19, 5.094408957625344e-19], 'source-value': [1.45771, 1.80267, 1.99262, 2.17522, 2.35186, 2.51022, 2.65642, 2.77448, 2.87044, 2.95069, 3.01722, 3.0705, 3.11287, 3.14738, 3.17663, 3.20101, 3.22256, 3.24473, 3.26438, 3.28023, 3.29201, 3.30009, 3.30522, 3.30702, 3.30608, 3.3029, 3.29679, 3.28684, 3.27194, 3.25058, 3.22076, 3.17968]}, 'basis-atom-coordinates': {'source-value': [[0, 0, 0], [0.5, 0.5, 0.5]]}, 'species': {'source-value': ['Al', 'Al']}, 'instance-id': 1}

# %%
model = 'MO_080526771943'
print(kimanalysis.shortcode(model))
print(kimanalysis.shortid(model))
print(kimanalysis.extendedid(model))
# Out:
# MO_080526771943
# MO_080526771943_000
# Four_Body_Mistriotis_Flytzanis_Farantos_Si__MO_080526771943_000

# %%
kimanalysis.listfiles(model)
# Out:
# ['Four_Body_Mistriotis_Flytzanis_Farantos_Si.params',
#  'LICENSE',
#  'Makefile',
#  'kimprovenance.edn',
#  'kimspec.edn']

# %%
kimanalysis.getfile(model, 'kimspec.edn', contentformat='edn')
# Out:
# {'author': 'Amit K Singh', 'contributor-id': '5d8c9931-da7e-48ed-86a5-0da65b7c3f13', 'description': 'This is a four-body Mistriotis-Flytzanis-Farantos potential model based on the KIM Model Driver  Four_Body_Mistriotis_Flytzanis_Farantos__MD_514777050453_000 . The cohesive energy of Silicon calculated through this model is 4.63 eV. With the help of molecular dynamics simulations, the melting temperature for this model was found to be around 2080 +/- 50 K which is the same as reported in Mistriotis et al. A graph between potential energy per atom vs temperature can be obtained by writing to the author. The latent heat for melting is 0.31 +/- 0.03 eV per atom whereas Mistriotis et al report 0.3 eV per atom.', 'domain': 'openkim.org', 'extended-id': 'Four_Body_Mistriotis_Flytzanis_Farantos_Si__MO_080526771943_000', 'kim-api-version': '1.6', 'maintainer-id': '5d8c9931-da7e-48ed-86a5-0da65b7c3f13', 'model-driver': 'Four_Body_Mistriotis_Flytzanis_Farantos__MD_514777050453_000', 'publication-year': '2016', 'source-citations': [{'author': 'Mistriotis, A. D. and Flytzanis, N. and Farantos, S. C.', 'doi': '10.1103/PhysRevB.39.1212', 'issue': '2', 'journal': 'Physical Review B', 'month': 'Jan', 'pages': '1212--1218', 'publisher': 'American Physical Society', 'recordkey': 'MO_080526771943_000a', 'recordtype': 'article', 'title': 'Potential model for silicon clusters', 'volume': '39', 'year': '1989'}, {'author': 'E. B. Tadmor and R. E. Miller', 'publisher': 'Cambridge University Press', 'recordkey': 'MO_080526771943_000b', 'recordtype': 'book', 'title': 'Modeling Materials: {C}ontinuum, Atomistic and Multiscale Techniques', 'year': '2011'}], 'species': ['Si'], 'title': 'A four-body Mistriotis-Flytzanis-Farantos Model for Silicon'}

# %%
r = kimanalysis.queryresults(test='TE_320860761056_001', model='MO_800509458712_001')

# %%
r.loc[0, 'test-result-id']
# Out:
# 'TE_320860761056_001-and-MO_800509458712_001-1525993487-tr'

# %%
ids[pd.notnull(ids)].iloc[0]
# Out:
# 'TE_002471259796_001-and-MO_080526771943_000-1500749148-tr'

# %%
r = kimanalysis.rawquery('obj', query={"type":'tr'}, limit=1)

# %%
r.loc[0, 'test-result-id']
# Out:
# 'TE_002471259796_001-and-MO_080526771943_000-1500749148-tr'

# %% [markdown]
# ## list ids for a given item type

# %%
kimanalysis.listids('model-driver', extended=True)
# Out:
# ['EDIP_BOP_C__MD_506186535567_001',
#  'EMT_Asap__MD_128315414717_002',
#  'Four_Body_Mistriotis_Flytzanis_Farantos__MD_514777050453_000',
#  'IMD_EAM__MD_113599595631_002',
#  'LennardJones612__MD_414112407348_002',
#  'MEAM_2NN__MD_111291751625_001',
#  'MSMEAM_Dynamo_Gibson_Baskes__MD_080127949983_000',
#  'MorseEIP_GuthikondaElliott_2009__MD_429561112321_001',
#  'Pair_LJ_Smooth__MD_716364606252_000',
#  'Pair_Lennard_Jones_Shifted__MD_498634107543_002',
#  'Pair_Lennard_Jones_Truncated__MD_132729421025_000',
#  'Pair_Morse_Shifted__MD_552566534109_001',
#  'Pair_Morse_Sigmoid__MD_199191711608_000',
#  'Pair_Morse_Smoothed__MD_093895395358_001',
#  'Three_Body_Stillinger_Weber_MX2__MD_242389978788_000',
#  'Three_Body_Stillinger_Weber__MD_335816936951_002',
#  'model_driver_PF_cubic_splines__MD_620624592962_001',
#  'model_driver_PF_quintic_splines__MD_543355979582_001',
#  'EAM_CubicNaturalSpline__MD_853402641673_001',
#  'EAM_Dynamo__MD_120291908751_004',
#  'EAM_QuinticClampedSpline__MD_532469991695_002',
#  'EAM_QuinticHermiteSpline__MD_029719603993_002',
#  'Tersoff_LAMMPS__MD_077075034781_002']

# %% [markdown]
# ## Switch between extended/short ids

# %%
modeldriver = 'EAM_Dynamo__MD_120291908751_004'
print(kimanalysis.extendedid(modeldriver))
print(kimanalysis.shortid(modeldriver))
print(kimanalysis.shortcode(modeldriver))
# Out:
# EAM_Dynamo__MD_120291908751_004
# MD_120291908751_004
# MD_120291908751

# %% [markdown]
# ## query items

# %%
import numpy as np

# %%
kimanalysis.queryitems('test', driver='ClusterEnergyAndForces__TD_000043093022_001')
# Out:
#      approved        author                        contributor-id  \
# 0        True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 1        True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 2        True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 3        True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 4        True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 5        True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 6        True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 7        True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 8        True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 9        True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 10       True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 11       True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 12       True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 13       True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 14       True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 15       True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 16       True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 17       True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 18       True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 19       True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 20       True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 21       True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 22       True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 23       True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 24       True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 25       True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 26       True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 27       True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 28       True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 29       True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# ..        ...           ...                                   ...
# 667      True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 668      True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 669      True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 670      True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 671      True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 672      True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 673      True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 674      True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 675      True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 676      True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 677      True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 678      True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 679      True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 680      True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 681      True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 682      True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 683      True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 684      True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 685      True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 686      True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 687      True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 688      True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 689      True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 690      True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 691      True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 692      True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 693      True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 694      True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 695      True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
# 696      True  Daniel Karls  4d62befd-21c4-42b8-a472-86132e6591f3
#
#                      created_on dependencies  \
# 0    2018-05-08 15:32:12.530517           []
# 1    2018-05-08 15:32:12.594516           []
# 2    2018-05-08 15:32:11.890532           []
# 3    2018-05-08 15:32:11.338545           []
# 4    2018-05-08 15:32:12.178525           []
# 5    2018-05-08 15:32:12.622515           []
# 6    2018-05-08 15:32:12.758512           []
# 7    2018-05-08 15:32:12.658514           []
# 8    2018-05-08 15:32:11.650537           []
# 9    2018-05-08 15:32:12.010529           []
# 10   2018-05-08 15:32:11.950531           []
# 11   2018-05-08 15:32:11.586539           []
# 12   2018-05-08 15:32:11.606539           []
# 13   2018-05-08 15:32:12.154526           []
# 14   2018-05-08 15:32:12.706513           []
# 15   2018-05-08 15:32:11.346545           []
# 16   2018-05-08 15:32:12.098527           []
# 17   2018-05-08 15:32:12.202525           []
# 18   2018-05-08 15:32:12.226524           []
# 19   2018-05-08 15:32:11.350544           []
# 20   2018-05-08 15:32:11.714536           []
# 21   2018-05-08 15:32:11.494541           []
# 22   2018-05-08 15:32:11.646538           []
# 23   2018-05-08 15:32:12.546517           []
# 24   2018-05-08 15:32:11.666537           []
# 25   2018-05-08 15:32:12.874509           []
# 26   2018-05-08 15:32:11.994529           []
# 27   2018-05-08 15:32:11.342545           []
# 28   2018-05-08 15:32:12.866509           []
# 29   2018-05-08 15:32:12.706513           []
# ..                          ...          ...
# 667  2018-05-08 15:32:12.454519           []
# 668  2018-05-08 15:32:12.602515           []
# 669  2018-05-08 15:32:12.606515           []
# 670  2018-05-08 15:32:11.850533           []
# 671  2018-05-08 15:32:12.370521           []
# 672  2018-05-08 15:32:11.578539           []
# 673  2018-05-08 15:32:12.674514           []
# 674  2018-05-08 15:32:11.594539           []
# 675  2018-05-08 15:32:12.210525           []
# 676  2018-05-08 15:32:12.378521           []
# 677  2018-05-08 15:32:12.190525           []
# 678  2018-05-08 15:32:12.514518           []
# 679  2018-05-08 15:32:12.310522           []
# 680  2018-05-08 15:32:12.286523           []
# 681  2018-05-08 15:32:11.430543           []
# 682  2018-05-08 15:32:11.498541           []
# 683  2018-05-08 15:32:11.258547           []
# 684  2018-05-08 15:32:12.790511           []
# 685  2018-05-08 15:32:11.590539           []
# 686  2018-05-08 15:32:12.226524           []
# 687  2018-05-08 15:32:11.310545           []
# 688  2018-05-08 15:32:11.518541           []
# 689  2018-05-08 15:32:11.310545           []
# 690  2018-05-08 15:32:11.854533           []
# 691  2018-05-08 15:32:11.270546           []
# 692  2018-05-08 15:32:11.450542           []
# 693  2018-05-08 15:32:12.466519           []
# 694  2018-05-08 15:32:12.222524           []
# 695  2018-05-08 15:32:12.946507           []
# 696  2018-05-08 15:32:11.638538           []
#
#                                            description  \
# 0    Computes the potential energy and forces of a ...
# 1    Computes the potential energy and forces of a ...
# 2    Computes the potential energy and forces of a ...
# 3    Computes the potential energy and forces of a ...
# 4    Computes the potential energy and forces of a ...
# 5    Computes the potential energy and forces of a ...
# 6    Computes the potential energy and forces of a ...
# 7    Computes the potential energy and forces of a ...
# 8    Computes the potential energy and forces of a ...
# 9    Computes the potential energy and forces of a ...
# 10   Computes the potential energy and forces of a ...
# 11   Computes the potential energy and forces of a ...
# 12   Computes the potential energy and forces of a ...
# 13   Computes the potential energy and forces of a ...
# 14   Computes the potential energy and forces of a ...
# 15   Computes the potential energy and forces of a ...
# 16   Computes the potential energy and forces of a ...
# 17   Computes the potential energy and forces of a ...
# 18   Computes the potential energy and forces of a ...
# 19   Computes the potential energy and forces of a ...
# 20   Computes the potential energy and forces of a ...
# 21   Computes the potential energy and forces of a ...
# 22   Computes the potential energy and forces of a ...
# 23   Computes the potential energy and forces of a ...
# 24   Computes the potential energy and forces of a ...
# 25   Computes the potential energy and forces of a ...
# 26   Computes the potential energy and forces of a ...
# 27   Computes the potential energy and forces of a ...
# 28   Computes the potential energy and forces of a ...
# 29   Computes the potential energy and forces of a ...
# ..                                                 ...
# 667  Computes the potential energy and forces of a ...
# 668  Computes the potential energy and forces of a ...
# 669  Computes the potential energy and forces of a ...
# 670  Computes the potential energy and forces of a ...
# 671  Computes the potential energy and forces of a ...
# 672  Computes the potential energy and forces of a ...
# 673  Computes the potential energy and forces of a ...
# 674  Computes the potential energy and forces of a ...
# 675  Computes the potential energy and forces of a ...
# 676  Computes the potential energy and forces of a ...
# 677  Computes the potential energy and forces of a ...
# 678  Computes the potential energy and forces of a ...
# 679  Computes the potential energy and forces of a ...
# 680  Computes the potential energy and forces of a ...
# 681  Computes the potential energy and forces of a ...
# 682  Computes the potential energy and forces of a ...
# 683  Computes the potential energy and forces of a ...
# 684  Computes the potential energy and forces of a ...
# 685  Computes the potential energy and forces of a ...
# 686  Computes the potential energy and forces of a ...
# 687  Computes the potential energy and forces of a ...
# 688  Computes the potential energy and forces of a ...
# 689  Computes the potential energy and forces of a ...
# 690  Computes the potential energy and forces of a ...
# 691  Computes the potential energy and forces of a ...
# 692  Computes the potential energy and forces of a ...
# 693  Computes the potential energy and forces of a ...
# 694  Computes the potential energy and forces of a ...
# 695  Computes the potential energy and forces of a ...
# 696  Computes the potential energy and forces of a ...
#
#                                             disclaimer       domain  \
# 0    See test driver source (ClusterEnergyAndForces...  openkim.org
# 1    See test driver source (ClusterEnergyAndForces...  openkim.org
# 2    See test driver source (ClusterEnergyAndForces...  openkim.org
# 3    See test driver source (ClusterEnergyAndForces...  openkim.org
# 4    See test driver source (ClusterEnergyAndForces...  openkim.org
# 5    See test driver source (ClusterEnergyAndForces...  openkim.org
# 6    See test driver source (ClusterEnergyAndForces...  openkim.org
# 7    See test driver source (ClusterEnergyAndForces...  openkim.org
# 8    See test driver source (ClusterEnergyAndForces...  openkim.org
# 9    See test driver source (ClusterEnergyAndForces...  openkim.org
# 10   See test driver source (ClusterEnergyAndForces...  openkim.org
# 11   See test driver source (ClusterEnergyAndForces...  openkim.org
# 12   See test driver source (ClusterEnergyAndForces...  openkim.org
# 13   See test driver source (ClusterEnergyAndForces...  openkim.org
# 14   See test driver source (ClusterEnergyAndForces...  openkim.org
# 15   See test driver source (ClusterEnergyAndForces...  openkim.org
# 16   See test driver source (ClusterEnergyAndForces...  openkim.org
# 17   See test driver source (ClusterEnergyAndForces...  openkim.org
# 18   See test driver source (ClusterEnergyAndForces...  openkim.org
# 19   See test driver source (ClusterEnergyAndForces...  openkim.org
# 20   See test driver source (ClusterEnergyAndForces...  openkim.org
# 21   See test driver source (ClusterEnergyAndForces...  openkim.org
# 22   See test driver source (ClusterEnergyAndForces...  openkim.org
# 23   See test driver source (ClusterEnergyAndForces...  openkim.org
# 24   See test driver source (ClusterEnergyAndForces...  openkim.org
# 25   See test driver source (ClusterEnergyAndForces...  openkim.org
# 26   See test driver source (ClusterEnergyAndForces...  openkim.org
# 27   See test driver source (ClusterEnergyAndForces...  openkim.org
# 28   See test driver source (ClusterEnergyAndForces...  openkim.org
# 29   See test driver source (ClusterEnergyAndForces...  openkim.org
# ..                                                 ...          ...
# 667  See test driver source (ClusterEnergyAndForces...  openkim.org
# 668  See test driver source (ClusterEnergyAndForces...  openkim.org
# 669  See test driver source (ClusterEnergyAndForces...  openkim.org
# 670  See test driver source (ClusterEnergyAndForces...  openkim.org
# 671  See test driver source (ClusterEnergyAndForces...  openkim.org
# 672  See test driver source (ClusterEnergyAndForces...  openkim.org
# 673  See test driver source (ClusterEnergyAndForces...  openkim.org
# 674  See test driver source (ClusterEnergyAndForces...  openkim.org
# 675  See test driver source (ClusterEnergyAndForces...  openkim.org
# 676  See test driver source (ClusterEnergyAndForces...  openkim.org
# 677  See test driver source (ClusterEnergyAndForces...  openkim.org
# 678  See test driver source (ClusterEnergyAndForces...  openkim.org
# 679  See test driver source (ClusterEnergyAndForces...  openkim.org
# 680  See test driver source (ClusterEnergyAndForces...  openkim.org
# 681  See test driver source (ClusterEnergyAndForces...  openkim.org
# 682  See test driver source (ClusterEnergyAndForces...  openkim.org
# 683  See test driver source (ClusterEnergyAndForces...  openkim.org
# 684  See test driver source (ClusterEnergyAndForces...  openkim.org
# 685  See test driver source (ClusterEnergyAndForces...  openkim.org
# 686  See test driver source (ClusterEnergyAndForces...  openkim.org
# 687  See test driver source (ClusterEnergyAndForces...  openkim.org
# 688  See test driver source (ClusterEnergyAndForces...  openkim.org
# 689  See test driver source (ClusterEnergyAndForces...  openkim.org
# 690  See test driver source (ClusterEnergyAndForces...  openkim.org
# 691  See test driver source (ClusterEnergyAndForces...  openkim.org
# 692  See test driver source (ClusterEnergyAndForces...  openkim.org
# 693  See test driver source (ClusterEnergyAndForces...  openkim.org
# 694  See test driver source (ClusterEnergyAndForces...  openkim.org
# 695  See test driver source (ClusterEnergyAndForces...  openkim.org
# 696  See test driver source (ClusterEnergyAndForces...  openkim.org
#
#                                           driver  \
# 0    ClusterEnergyAndForces__TD_000043093022_001
# 1    ClusterEnergyAndForces__TD_000043093022_001
# 2    ClusterEnergyAndForces__TD_000043093022_001
# 3    ClusterEnergyAndForces__TD_000043093022_001
# 4    ClusterEnergyAndForces__TD_000043093022_001
# 5    ClusterEnergyAndForces__TD_000043093022_001
# 6    ClusterEnergyAndForces__TD_000043093022_001
# 7    ClusterEnergyAndForces__TD_000043093022_001
# 8    ClusterEnergyAndForces__TD_000043093022_001
# 9    ClusterEnergyAndForces__TD_000043093022_001
# 10   ClusterEnergyAndForces__TD_000043093022_001
# 11   ClusterEnergyAndForces__TD_000043093022_001
# 12   ClusterEnergyAndForces__TD_000043093022_001
# 13   ClusterEnergyAndForces__TD_000043093022_001
# 14   ClusterEnergyAndForces__TD_000043093022_001
# 15   ClusterEnergyAndForces__TD_000043093022_001
# 16   ClusterEnergyAndForces__TD_000043093022_001
# 17   ClusterEnergyAndForces__TD_000043093022_001
# 18   ClusterEnergyAndForces__TD_000043093022_001
# 19   ClusterEnergyAndForces__TD_000043093022_001
# 20   ClusterEnergyAndForces__TD_000043093022_001
# 21   ClusterEnergyAndForces__TD_000043093022_001
# 22   ClusterEnergyAndForces__TD_000043093022_001
# 23   ClusterEnergyAndForces__TD_000043093022_001
# 24   ClusterEnergyAndForces__TD_000043093022_001
# 25   ClusterEnergyAndForces__TD_000043093022_001
# 26   ClusterEnergyAndForces__TD_000043093022_001
# 27   ClusterEnergyAndForces__TD_000043093022_001
# 28   ClusterEnergyAndForces__TD_000043093022_001
# 29   ClusterEnergyAndForces__TD_000043093022_001
# ..                                           ...
# 667  ClusterEnergyAndForces__TD_000043093022_001
# 668  ClusterEnergyAndForces__TD_000043093022_001
# 669  ClusterEnergyAndForces__TD_000043093022_001
# 670  ClusterEnergyAndForces__TD_000043093022_001
# 671  ClusterEnergyAndForces__TD_000043093022_001
# 672  ClusterEnergyAndForces__TD_000043093022_001
# 673  ClusterEnergyAndForces__TD_000043093022_001
# 674  ClusterEnergyAndForces__TD_000043093022_001
# 675  ClusterEnergyAndForces__TD_000043093022_001
# 676  ClusterEnergyAndForces__TD_000043093022_001
# 677  ClusterEnergyAndForces__TD_000043093022_001
# 678  ClusterEnergyAndForces__TD_000043093022_001
# 679  ClusterEnergyAndForces__TD_000043093022_001
# 680  ClusterEnergyAndForces__TD_000043093022_001
# 681  ClusterEnergyAndForces__TD_000043093022_001
# 682  ClusterEnergyAndForces__TD_000043093022_001
# 683  ClusterEnergyAndForces__TD_000043093022_001
# 684  ClusterEnergyAndForces__TD_000043093022_001
# 685  ClusterEnergyAndForces__TD_000043093022_001
# 686  ClusterEnergyAndForces__TD_000043093022_001
# 687  ClusterEnergyAndForces__TD_000043093022_001
# 688  ClusterEnergyAndForces__TD_000043093022_001
# 689  ClusterEnergyAndForces__TD_000043093022_001
# 690  ClusterEnergyAndForces__TD_000043093022_001
# 691  ClusterEnergyAndForces__TD_000043093022_001
# 692  ClusterEnergyAndForces__TD_000043093022_001
# 693  ClusterEnergyAndForces__TD_000043093022_001
# 694  ClusterEnergyAndForces__TD_000043093022_001
# 695  ClusterEnergyAndForces__TD_000043093022_001
# 696  ClusterEnergyAndForces__TD_000043093022_001
#
#                                            extended-id   ...     \
# 0    ClusterEnergyAndForces_3atom_Si__TE_0024712597...   ...
# 1    ClusterEnergyAndForces_3atom_Si__TE_0036433087...   ...
# 2    ClusterEnergyAndForces_3atom_Si__TE_0208653775...   ...
# 3    ClusterEnergyAndForces_3atom_Si__TE_0304370345...   ...
# 4    ClusterEnergyAndForces_3atom_Si__TE_0310863382...   ...
# 5    ClusterEnergyAndForces_3atom_Si__TE_0359804113...   ...
# 6    ClusterEnergyAndForces_3atom_Si__TE_0386005006...   ...
# 7    ClusterEnergyAndForces_3atom_Si__TE_0392680862...   ...
# 8    ClusterEnergyAndForces_3atom_Si__TE_0543300947...   ...
# 9    ClusterEnergyAndForces_3atom_Si__TE_0548402541...   ...
# 10   ClusterEnergyAndForces_3atom_Si__TE_0601334637...   ...
# 11   ClusterEnergyAndForces_3atom_Si__TE_0639963201...   ...
# 12   ClusterEnergyAndForces_3atom_Si__TE_0642664125...   ...
# 13   ClusterEnergyAndForces_3atom_Si__TE_0723371631...   ...
# 14   ClusterEnergyAndForces_3atom_Si__TE_0841880804...   ...
# 15   ClusterEnergyAndForces_3atom_Si__TE_0961874258...   ...
# 16   ClusterEnergyAndForces_3atom_Si__TE_1052050074...   ...
# 17   ClusterEnergyAndForces_3atom_Si__TE_1159428493...   ...
# 18   ClusterEnergyAndForces_3atom_Si__TE_1424144888...   ...
# 19   ClusterEnergyAndForces_3atom_Si__TE_1480244002...   ...
# 20   ClusterEnergyAndForces_3atom_Si__TE_1554900864...   ...
# 21   ClusterEnergyAndForces_3atom_Si__TE_1638075598...   ...
# 22   ClusterEnergyAndForces_3atom_Si__TE_1744642663...   ...
# 23   ClusterEnergyAndForces_3atom_Si__TE_2010267736...   ...
# 24   ClusterEnergyAndForces_3atom_Si__TE_2017806159...   ...
# 25   ClusterEnergyAndForces_3atom_Si__TE_2085715146...   ...
# 26   ClusterEnergyAndForces_3atom_Si__TE_2105669636...   ...
# 27   ClusterEnergyAndForces_3atom_Si__TE_2109851046...   ...
# 28   ClusterEnergyAndForces_3atom_Si__TE_2120447695...   ...
# 29   ClusterEnergyAndForces_3atom_Si__TE_2193674851...   ...
# ..                                                 ...   ...
# 667  ClusterEnergyAndForces_7atom_Si__TE_4595916576...   ...
# 668  ClusterEnergyAndForces_7atom_Si__TE_4984762773...   ...
# 669  ClusterEnergyAndForces_7atom_Si__TE_5572393413...   ...
# 670  ClusterEnergyAndForces_7atom_Si__TE_6080390594...   ...
# 671  ClusterEnergyAndForces_7atom_Si__TE_6510410567...   ...
# 672  ClusterEnergyAndForces_7atom_Si__TE_6581103083...   ...
# 673  ClusterEnergyAndForces_7atom_Si__TE_6642748497...   ...
# 674  ClusterEnergyAndForces_7atom_Si__TE_6778248193...   ...
# 675  ClusterEnergyAndForces_7atom_Si__TE_6974295082...   ...
# 676  ClusterEnergyAndForces_7atom_Si__TE_7024056658...   ...
# 677  ClusterEnergyAndForces_7atom_Si__TE_7360640795...   ...
# 678  ClusterEnergyAndForces_7atom_Si__TE_7439075134...   ...
# 679  ClusterEnergyAndForces_7atom_Si__TE_7546061271...   ...
# 680  ClusterEnergyAndForces_7atom_Si__TE_8004285180...   ...
# 681  ClusterEnergyAndForces_7atom_Si__TE_8008133400...   ...
# 682  ClusterEnergyAndForces_7atom_Si__TE_8285855002...   ...
# 683  ClusterEnergyAndForces_7atom_Si__TE_8318067434...   ...
# 684  ClusterEnergyAndForces_7atom_Si__TE_8372832033...   ...
# 685  ClusterEnergyAndForces_7atom_Si__TE_8408563625...   ...
# 686  ClusterEnergyAndForces_7atom_Si__TE_8478102189...   ...
# 687  ClusterEnergyAndForces_7atom_Si__TE_8524174116...   ...
# 688  ClusterEnergyAndForces_7atom_Si__TE_8623722451...   ...
# 689  ClusterEnergyAndForces_7atom_Si__TE_8670319895...   ...
# 690  ClusterEnergyAndForces_7atom_Si__TE_8696785279...   ...
# 691  ClusterEnergyAndForces_7atom_Si__TE_8939521889...   ...
# 692  ClusterEnergyAndForces_7atom_Si__TE_9293867107...   ...
# 693  ClusterEnergyAndForces_7atom_Si__TE_9323503956...   ...
# 694  ClusterEnergyAndForces_7atom_Si__TE_9460256090...   ...
# 695  ClusterEnergyAndForces_7atom_Si__TE_9647747543...   ...
# 696  ClusterEnergyAndForces_7atom_Si__TE_9851478305...   ...
#
#     pipeline-api-version publication-year runner             short-id  \
# 0                    1.0             2014   True  TE_002471259796_001
# 1                    1.0             2014   True  TE_003643308767_001
# 2                    1.0             2014   True  TE_020865377514_001
# 3                    1.0             2014   True  TE_030437034568_001
# 4                    1.0             2014   True  TE_031086338232_001
# 5                    1.0             2014   True  TE_035980411356_001
# 6                    1.0             2014   True  TE_038600500690_001
# 7                    1.0             2014   True  TE_039268086216_001
# 8                    1.0             2014   True  TE_054330094742_001
# 9                    1.0             2014   True  TE_054840254157_001
# 10                   1.0             2014   True  TE_060133463731_001
# 11                   1.0             2014   True  TE_063996320154_001
# 12                   1.0             2014   True  TE_064266412548_001
# 13                   1.0             2014   True  TE_072337163180_001
# 14                   1.0             2014   True  TE_084188080431_001
# 15                   1.0             2014   True  TE_096187425822_001
# 16                   1.0             2014   True  TE_105205007411_001
# 17                   1.0             2014   True  TE_115942849365_001
# 18                   1.0             2014   True  TE_142414488895_001
# 19                   1.0             2014   True  TE_148024400299_001
# 20                   1.0             2014   True  TE_155490086486_001
# 21                   1.0             2014   True  TE_163807559834_001
# 22                   1.0             2014   True  TE_174464266362_001
# 23                   1.0             2014   True  TE_201026773639_001
# 24                   1.0             2014   True  TE_201780615933_001
# 25                   1.0             2014   True  TE_208571514677_001
# 26                   1.0             2014   True  TE_210566963632_001
# 27                   1.0             2014   True  TE_210985104651_001
# 28                   1.0             2014   True  TE_212044769530_001
# 29                   1.0             2014   True  TE_219367485129_001
# ..                   ...              ...    ...                  ...
# 667                  1.0             2014   True  TE_459591657602_001
# 668                  1.0             2014   True  TE_498476277337_001
# 669                  1.0             2014   True  TE_557239341342_001
# 670                  1.0             2014   True  TE_608039059493_001
# 671                  1.0             2014   True  TE_651041056797_001
# 672                  1.0             2014   True  TE_658110308301_001
# 673                  1.0             2014   True  TE_664274849771_001
# 674                  1.0             2014   True  TE_677824819309_001
# 675                  1.0             2014   True  TE_697429508294_001
# 676                  1.0             2014   True  TE_702405665861_001
# 677                  1.0             2014   True  TE_736064079559_001
# 678                  1.0             2014   True  TE_743907513442_001
# 679                  1.0             2014   True  TE_754606127158_001
# 680                  1.0             2014   True  TE_800428518000_001
# 681                  1.0             2014   True  TE_800813340022_001
# 682                  1.0             2014   True  TE_828585500282_001
# 683                  1.0             2014   True  TE_831806743438_001
# 684                  1.0             2014   True  TE_837283203301_001
# 685                  1.0             2014   True  TE_840856362524_001
# 686                  1.0             2014   True  TE_847810218970_001
# 687                  1.0             2014   True  TE_852417411678_001
# 688                  1.0             2014   True  TE_862372245108_001
# 689                  1.0             2014   True  TE_867031989556_001
# 690                  1.0             2014   True  TE_869678527986_001
# 691                  1.0             2014   True  TE_893952188963_001
# 692                  1.0             2014   True  TE_929386710714_001
# 693                  1.0             2014   True  TE_932350395680_001
# 694                  1.0             2014   True  TE_946025609012_001
# 695                  1.0             2014   True  TE_964774754346_001
# 696                  1.0             2014   True  TE_985147830556_001
#
#            shortcode species                                  test-driver  \
# 0    TE_002471259796    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 1    TE_003643308767    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 2    TE_020865377514    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 3    TE_030437034568    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 4    TE_031086338232    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 5    TE_035980411356    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 6    TE_038600500690    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 7    TE_039268086216    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 8    TE_054330094742    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 9    TE_054840254157    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 10   TE_060133463731    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 11   TE_063996320154    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 12   TE_064266412548    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 13   TE_072337163180    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 14   TE_084188080431    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 15   TE_096187425822    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 16   TE_105205007411    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 17   TE_115942849365    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 18   TE_142414488895    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 19   TE_148024400299    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 20   TE_155490086486    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 21   TE_163807559834    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 22   TE_174464266362    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 23   TE_201026773639    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 24   TE_201780615933    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 25   TE_208571514677    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 26   TE_210566963632    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 27   TE_210985104651    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 28   TE_212044769530    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 29   TE_219367485129    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# ..               ...     ...                                          ...
# 667  TE_459591657602    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 668  TE_498476277337    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 669  TE_557239341342    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 670  TE_608039059493    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 671  TE_651041056797    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 672  TE_658110308301    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 673  TE_664274849771    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 674  TE_677824819309    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 675  TE_697429508294    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 676  TE_702405665861    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 677  TE_736064079559    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 678  TE_743907513442    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 679  TE_754606127158    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 680  TE_800428518000    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 681  TE_800813340022    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 682  TE_828585500282    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 683  TE_831806743438    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 684  TE_837283203301    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 685  TE_840856362524    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 686  TE_847810218970    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 687  TE_852417411678    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 688  TE_862372245108    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 689  TE_867031989556    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 690  TE_869678527986    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 691  TE_893952188963    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 692  TE_929386710714    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 693  TE_932350395680    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 694  TE_946025609012    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 695  TE_964774754346    [Si]  ClusterEnergyAndForces__TD_000043093022_001
# 696  TE_985147830556    [Si]  ClusterEnergyAndForces__TD_000043093022_001
#
#                                                  title type  version
# 0    Conjugate gradient relaxation of random atomic...   te        1
# 1    Conjugate gradient relaxation of random atomic...   te        1
# 2    Conjugate gradient relaxation of random atomic...   te        1
# 3    Conjugate gradient relaxation of random atomic...   te        1
# 4    Conjugate gradient relaxation of random atomic...   te        1
# 5    Conjugate gradient relaxation of random atomic...   te        1
# 6    Conjugate gradient relaxation of random atomic...   te        1
# 7    Conjugate gradient relaxation of random atomic...   te        1
# 8    Conjugate gradient relaxation of random atomic...   te        1
# 9    Conjugate gradient relaxation of random atomic...   te        1
# 10   Conjugate gradient relaxation of random atomic...   te        1
# 11   Conjugate gradient relaxation of random atomic...   te        1
# 12   Conjugate gradient relaxation of random atomic...   te        1
# 13   Conjugate gradient relaxation of random atomic...   te        1
# 14   Conjugate gradient relaxation of random atomic...   te        1
# 15   Conjugate gradient relaxation of random atomic...   te        1
# 16   Conjugate gradient relaxation of random atomic...   te        1
# 17   Conjugate gradient relaxation of random atomic...   te        1
# 18   Conjugate gradient relaxation of random atomic...   te        1
# 19   Conjugate gradient relaxation of random atomic...   te        1
# 20   Conjugate gradient relaxation of random atomic...   te        1
# 21   Conjugate gradient relaxation of random atomic...   te        1
# 22   Conjugate gradient relaxation of random atomic...   te        1
# 23   Conjugate gradient relaxation of random atomic...   te        1
# 24   Conjugate gradient relaxation of random atomic...   te        1
# 25   Conjugate gradient relaxation of random atomic...   te        1
# 26   Conjugate gradient relaxation of random atomic...   te        1
# 27   Conjugate gradient relaxation of random atomic...   te        1
# 28   Conjugate gradient relaxation of random atomic...   te        1
# 29   Conjugate gradient relaxation of random atomic...   te        1
# ..                                                 ...  ...      ...
# 667  Conjugate gradient relaxation of random atomic...   te        1
# 668  Conjugate gradient relaxation of random atomic...   te        1
# 669  Conjugate gradient relaxation of random atomic...   te        1
# 670  Conjugate gradient relaxation of random atomic...   te        1
# 671  Conjugate gradient relaxation of random atomic...   te        1
# 672  Conjugate gradient relaxation of random atomic...   te        1
# 673  Conjugate gradient relaxation of random atomic...   te        1
# 674  Conjugate gradient relaxation of random atomic...   te        1
# 675  Conjugate gradient relaxation of random atomic...   te        1
# 676  Conjugate gradient relaxation of random atomic...   te        1
# 677  Conjugate gradient relaxation of random atomic...   te        1
# 678  Conjugate gradient relaxation of random atomic...   te        1
# 679  Conjugate gradient relaxation of random atomic...   te        1
# 680  Conjugate gradient relaxation of random atomic...   te        1
# 681  Conjugate gradient relaxation of random atomic...   te        1
# 682  Conjugate gradient relaxation of random atomic...   te        1
# 683  Conjugate gradient relaxation of random atomic...   te        1
# 684  Conjugate gradient relaxation of random atomic...   te        1
# 685  Conjugate gradient relaxation of random atomic...   te        1
# 686  Conjugate gradient relaxation of random atomic...   te        1
# 687  Conjugate gradient relaxation of random atomic...   te        1
# 688  Conjugate gradient relaxation of random atomic...   te        1
# 689  Conjugate gradient relaxation of random atomic...   te        1
# 690  Conjugate gradient relaxation of random atomic...   te        1
# 691  Conjugate gradient relaxation of random atomic...   te        1
# 692  Conjugate gradient relaxation of random atomic...   te        1
# 693  Conjugate gradient relaxation of random atomic...   te        1
# 694  Conjugate gradient relaxation of random atomic...   te        1
# 695  Conjugate gradient relaxation of random atomic...   te        1
# 696  Conjugate gradient relaxation of random atomic...   te        1
#
# [697 rows x 34 columns]

# %% [markdown]
# ## Get single item using item id

# %%
kimanalysis.getitem('LammpsExample__TD_567444853524_004')
# Out:
# approved                                                                 True
# author                                                           Daniel Karls
# contributor-id                           4d62befd-21c4-42b8-a472-86132e6591f3
# created_on                                         2018-07-12 22:49:25.400736
# description                 This example Test Driver illustrates the use o...
# domain                                                            openkim.org
# driver                                                                   True
# executables                                                          [runner]
# extended-id                                LammpsExample__TD_567444853524_004
# inserted_on                                        2018-07-13 03:49:25.671370
# kim-api-version                                                         1.9.0
# kimcode                                    LammpsExample__TD_567444853524_004
# kimid-number                                                     567444853524
# kimid-prefix                                                    LammpsExample
# kimid-typecode                                                             td
# kimid-version                                                             004
# kimid-version-as-integer                                                    4
# kimnum                                                           567444853524
# latest                                                                   True
# maintainer-id                            4d62befd-21c4-42b8-a472-86132e6591f3
# makeable                                                                 True
# name                                                            LammpsExample
# path                                    td/LammpsExample__TD_567444853524_004
# properties                  [tag:staff@noreply.openkim.org,2014-04-15:prop...
# publication-year                                                         2018
# short-id                                                  TD_567444853524_004
# shortcode                                                     TD_567444853524
# simulator-name                                                         LAMMPS
# title                       LammpsExample: cohesive energy and equilibrium...
# type                                                                       td
# version                                                                     4
# Name: 0, dtype: object

# %% [markdown]
# ## Query results

# %% [markdown]
# Get all model-drivers alphabetically

# %%
test = kimanalysis.queryitems('test', limit=1).iloc[0]['short-id']

kimanalysis.queryresults(test=test)
# Out:
#                     created_on                 inserted_on  instance-id  \
# 0   2018-05-08 14:27:57.137260  2018-05-08 23:56:14.088824            1
# 1   2018-05-08 14:29:13.507522  2018-05-08 23:56:14.145627            1
# 2   2018-05-08 14:28:54.711950  2018-05-08 23:56:14.202288            1
# 3   2018-05-08 14:27:56.253280  2018-05-08 23:56:14.484222            1
# 4   2018-05-08 14:27:53.189350  2018-05-08 23:56:14.541243            1
# 5   2018-05-08 14:28:55.243938  2018-05-08 23:56:14.656986            1
# 6   2018-05-08 14:28:03.357118  2018-05-08 23:56:14.713443            1
# 7   2018-05-08 14:29:08.439638  2018-05-08 23:56:14.823630            1
# 8   2018-05-09 20:57:54.892939  2018-05-10 02:34:44.854782            1
# 9   2018-06-18 19:51:24.878014  2018-06-19 01:25:32.401177            1
# 10  2018-06-18 20:20:28.366965  2018-06-19 01:45:55.523597            1
# 11  2018-06-18 20:50:24.949269  2018-06-19 02:07:27.197544            1
# 12  2018-06-18 21:18:03.065480  2018-06-19 02:30:11.271241            1
# 13  2018-06-18 21:46:43.944176  2018-06-19 02:51:23.022421            1
# 14  2018-06-18 22:15:07.410182  2018-06-19 03:15:07.731690            1
#
#     latest                                              model  \
# 0     True  Four_Body_Mistriotis_Flytzanis_Farantos_Si__MO...
# 1     True  Three_Body_Stillinger_Weber_Balamane_Si__MO_11...
# 2     True  Three_Body_Stillinger_Weber_Hauch_Brittle_Si__...
# 3     True  Three_Body_Stillinger_Weber_Balamane_Hauch_Bri...
# 4     True  Three_Body_Stillinger_Weber_Si__MO_40551205666...
# 5     True  Three_Body_Stillinger_Weber_Zhang_Silicene_Mod...
# 6     True  Three_Body_Stillinger_Weber_Zhang_Silicene_Mod...
# 7     True    EDIP_BOP_Bazant_Kaxiras_Si__MO_958932894036_001
# 8     True  LennardJones612_UniversalShifted__MO_959249795...
# 9     True  Tersoff_LAMMPS_Erhart_Albe_CSi__MO_90398758584...
# 10    True  Tersoff_LAMMPS_Erhart_Albe_SiII_CSi__MO_408791...
# 11    True  Tersoff_LAMMPS_Tersoff_PRB37_1988_Si__MO_24509...
# 12    True  Tersoff_LAMMPS_Tersoff_PRB38_1988_Si__MO_18645...
# 13    True  Tersoff_LAMMPS_Tersoff_PRB39_1989_CSi__MO_1715...
# 14    True  Tersoff_LAMMPS_Tersoff_PRB39_1989_GeSi__MO_350...
#
#                                           property-id  \
# 0   tag:staff@noreply.openkim.org,2014-04-15:prope...
# 1   tag:staff@noreply.openkim.org,2014-04-15:prope...
# 2   tag:staff@noreply.openkim.org,2014-04-15:prope...
# 3   tag:staff@noreply.openkim.org,2014-04-15:prope...
# 4   tag:staff@noreply.openkim.org,2014-04-15:prope...
# 5   tag:staff@noreply.openkim.org,2014-04-15:prope...
# 6   tag:staff@noreply.openkim.org,2014-04-15:prope...
# 7   tag:staff@noreply.openkim.org,2014-04-15:prope...
# 8   tag:staff@noreply.openkim.org,2014-04-15:prope...
# 9   tag:staff@noreply.openkim.org,2014-04-15:prope...
# 10  tag:staff@noreply.openkim.org,2014-04-15:prope...
# 11  tag:staff@noreply.openkim.org,2014-04-15:prope...
# 12  tag:staff@noreply.openkim.org,2014-04-15:prope...
# 13  tag:staff@noreply.openkim.org,2014-04-15:prope...
# 14  tag:staff@noreply.openkim.org,2014-04-15:prope...
#
#                          relaxed-configuration-forces  \
# 0   [[8.4e-05, -5.56e-05, -0.0002337], [9.76e-05, ...
# 1   [[-5.5e-06, -5.1e-06, -2.83e-05], [2.78e-05, -...
# 2   [[-0.0040279, 0.0012364, 0.004098], [0.0016554...
# 3   [[-0.0040781, 0.0013452, 0.0046141], [0.001772...
# 4   [[0.0007582, 1.1e-06, 0.0003928], [3e-06, -0.0...
# 5   [[-0.0029292, 0.0007402, 0.0021888], [-0.00073...
# 6   [[0.0001419, -1.58e-05, -6e-06], [8.11e-05, -3...
# 7   [[-0.0018145, -9.6e-06, -0.0009745], [0.000811...
# 8   [[0.0003866, 3.7e-06, 0.0002159], [-1.94e-05, ...
# 9   [[-0.000761, -8.1e-06, -0.0004293], [-6e-07, 0...
# 10  [[0.0006878, -4.52e-05, 0.0001262], [-0.000498...
# 11  [[9.75e-05, -5.6e-06, 2.18e-05], [0.0011571, -...
# 12  [[0.0002334, 4.2e-06, 0.00014], [8.22e-05, -9....
# 13  [[-2.09e-05, -2e-07, -1.16e-05], [2.11e-05, -4...
# 14  [[-2.09e-05, -2e-07, -1.16e-05], [2.11e-05, -4...
#
#                       relaxed-configuration-positions  \
# 0   [[-0.2063096, 0.5705636, 0.6360511], [1.024212...
# 1   [[-0.2985835, 0.5696979, 0.5846091], [1.026755...
# 2   [[0.2034722, 0.5745197, 0.8650575], [0.4705104...
# 3   [[0.2034774, 0.5745189, 0.8650559], [0.4704889...
# 4   [[-0.2986136, 0.569698, 0.5845942], [1.0267572...
# 5   [[0.2389494, 0.5750782, 0.8859594], [0.4978511...
# 6   [[-0.2237741, 0.5704247, 0.6264388], [1.024790...
# 7   [[-0.233046, 0.570122, 0.6201962], [1.0240656,...
# 8   [[-0.1263652, 0.5715944, 0.6820173], [1.023271...
# 9   [[-0.2022463, 0.5705982, 0.638299], [1.0241106...
# 10  [[-0.1926145, 0.570688, 0.6436657], [1.0238608...
# 11  [[-0.1727158, 0.5708787, 0.6547792], [1.023243...
# 12  [[-0.2671456, 0.5700152, 0.6022465], [1.025993...
# 13  [[-0.2669714, 0.5699274, 0.6018988], [1.025604...
# 14  [[-0.2669714, 0.5699274, 0.6018988], [1.025604...
#
#     relaxed-potential-energy       species  \
# 0                  -6.562444  [Si, Si, Si]
# 1                  -4.741968  [Si, Si, Si]
# 2                  -4.336395  [Si, Si, Si]
# 3                  -4.629994  [Si, Si, Si]
# 4                  -4.441268  [Si, Si, Si]
# 5                  -3.588875  [Si, Si, Si]
# 6                  -3.651734  [Si, Si, Si]
# 7                  -7.535362  [Si, Si, Si]
# 8                  -9.513632  [Si, Si, Si]
# 9                  -6.542208  [Si, Si, Si]
# 10                 -6.909223  [Si, Si, Si]
# 11                 -7.871062  [Si, Si, Si]
# 12                 -4.809282  [Si, Si, Si]
# 13                 -4.808736  [Si, Si, Si]
# 14                 -4.808736  [Si, Si, Si]
#
#                                                  test  \
# 0   ClusterEnergyAndForces_3atom_Si__TE_0024712597...
# 1   ClusterEnergyAndForces_3atom_Si__TE_0024712597...
# 2   ClusterEnergyAndForces_3atom_Si__TE_0024712597...
# 3   ClusterEnergyAndForces_3atom_Si__TE_0024712597...
# 4   ClusterEnergyAndForces_3atom_Si__TE_0024712597...
# 5   ClusterEnergyAndForces_3atom_Si__TE_0024712597...
# 6   ClusterEnergyAndForces_3atom_Si__TE_0024712597...
# 7   ClusterEnergyAndForces_3atom_Si__TE_0024712597...
# 8   ClusterEnergyAndForces_3atom_Si__TE_0024712597...
# 9   ClusterEnergyAndForces_3atom_Si__TE_0024712597...
# 10  ClusterEnergyAndForces_3atom_Si__TE_0024712597...
# 11  ClusterEnergyAndForces_3atom_Si__TE_0024712597...
# 12  ClusterEnergyAndForces_3atom_Si__TE_0024712597...
# 13  ClusterEnergyAndForces_3atom_Si__TE_0024712597...
# 14  ClusterEnergyAndForces_3atom_Si__TE_0024712597...
#
#                                        test-result-id  \
# 0   TE_002471259796_001-and-MO_080526771943_000-15...
# 1   TE_002471259796_001-and-MO_113686039439_002-15...
# 2   TE_002471259796_001-and-MO_119167353542_002-15...
# 3   TE_002471259796_001-and-MO_381114941873_000-15...
# 4   TE_002471259796_001-and-MO_405512056662_003-15...
# 5   TE_002471259796_001-and-MO_475612090600_002-15...
# 6   TE_002471259796_001-and-MO_800412945727_002-15...
# 7   TE_002471259796_001-and-MO_958932894036_001-15...
# 8   TE_002471259796_001-and-MO_959249795837_002-15...
# 9   TE_002471259796_001-and-MO_903987585848_002-15...
# 10  TE_002471259796_001-and-MO_408791041969_001-15...
# 11  TE_002471259796_001-and-MO_245095684871_001-15...
# 12  TE_002471259796_001-and-MO_186459956893_001-15...
# 13  TE_002471259796_001-and-MO_171585019474_001-15...
# 14  TE_002471259796_001-and-MO_350526375143_001-15...
#
#                        unrelaxed-configuration-forces  \
# 0   [[-61.2530081, 0.600406, -28.2981964], [9.2767...
# 1   [[-65.9240524, 0.5052313, -31.1579237], [8.575...
# 2   [[-65.5231813, 0.3886392, -31.5336055], [6.615...
# 3   [[-69.9594863, 0.4149524, -33.6686161], [7.063...
# 4   [[-61.7436416, 0.4731933, -29.182121], [8.0316...
# 5   [[-42.0627137, 0.3057942, -19.962733], [4.6979...
# 6   [[-42.9456256, 0.3536781, -20.1753283], [5.548...
# 7   [[-16.552623, -0.0971359, -8.9384498], [1.6559...
# 8   [[-4525.8578194, 161.7681926, -1506.4042156], ...
# 9   [[-79.2177435, 0.6512709, -37.2211287], [11.68...
# 10  [[-73.1871233, 0.5817486, -34.4868743], [10.66...
# 11  [[-93.1928563, 0.8920957, -43.1605164], [16.41...
# 12  [[-72.5762607, 0.5689974, -34.2383338], [7.301...
# 13  [[-77.0954391, 0.4759453, -37.0099227], [10.61...
# 14  [[-77.0954391, 0.4759453, -37.0099227], [10.61...
#
#                     unrelaxed-configuration-positions  \
# 0   [[0.3882469, 0.572907, 0.9514094], [0.8098832,...
# 1   [[0.3882469, 0.572907, 0.9514094], [0.8098832,...
# 2   [[0.3882469, 0.572907, 0.9514094], [0.8098832,...
# 3   [[0.3882469, 0.572907, 0.9514094], [0.8098832,...
# 4   [[0.3882469, 0.572907, 0.9514094], [0.8098832,...
# 5   [[0.3882469, 0.572907, 0.9514094], [0.8098832,...
# 6   [[0.3882469, 0.572907, 0.9514094], [0.8098832,...
# 7   [[0.3882469, 0.572907, 0.9514094], [0.8098832,...
# 8   [[0.3882469, 0.572907, 0.9514094], [0.8098832,...
# 9   [[0.3882469, 0.572907, 0.9514094], [0.8098832,...
# 10  [[0.3882469, 0.572907, 0.9514094], [0.8098832,...
# 11  [[0.3882469, 0.572907, 0.9514094], [0.8098832,...
# 12  [[0.3882469, 0.572907, 0.9514094], [0.8098832,...
# 13  [[0.3882469, 0.572907, 0.9514094], [0.8098832,...
# 14  [[0.3882469, 0.572907, 0.9514094], [0.8098832,...
#
#     unrelaxed-potential-energy
# 0                    18.251255
# 1                    26.053643
# 2                    32.481751
# 3                    34.680957
# 4                    24.401516
# 5                    16.153223
# 6                    14.698220
# 7                     3.946812
# 8                   726.656260
# 9                    25.331186
# 10                   22.996949
# 11                   26.036436
# 12                   28.800734
# 13                   30.204267
# 14                   30.204267

# %% [markdown]
# Get models sorted by species

# %% [markdown]
# ## get files

# %% [markdown]
# Get an item's README file

# %%
md_id = 'EAM_Dynamo__MD_120291908751_004'
filename = 'EAM.hpp'
filecontents = kimanalysis.getitemfile(md_id, filename)
print(filecontents)
# Out:
# //
# // CDDL HEADER START
# //
# // The contents of this file are subject to the terms of the Common Development
# // and Distribution License Version 1.0 (the "License").
# //
# // You can obtain a copy of the license at
# // http://www.opensource.org/licenses/CDDL-1.0.  See the License for the
# // specific language governing permissions and limitations under the License.
# //
# // When distributing Covered Code, include this CDDL HEADER in each file and
# // include the License file in a prominent location with the name LICENSE.CDDL.
# // If applicable, add the following below this CDDL HEADER, with the fields
# // enclosed by brackets "[]" replaced with your own identifying information:
# //
# // Portions Copyright (c) [yyyy] [name of copyright owner]. All rights reserved.
# //
# // CDDL HEADER END
# //
#
# //
# // Copyright (c) 2013--2017, Regents of the University of Minnesota.
# // All rights reserved.
# //
# // Contributors:
# //    Ryan S. Elliott
# //
#
#
# #ifndef EAM_HPP_
# #define EAM_HPP_
#
# #include "KIM_API.h"
#
# extern "C"
# {
#   int model_driver_init(void* km, char* paramfile_names, int* nmstrlen,
#                         int* numparamfiles);
# }
#
# class EAM_Implementation;
#
# class EAM
# {
#  public:
#   EAM(KIM_API_model* const pkim,
#              char const* const parameterFileNames,
#              int const parameterFileNameLength,
#              int const numberParameterFiles,
#              int* const ier);
#   ~EAM();
#
#   // no need to make these "extern" since KIM will only access them
#   // via function pointers.  "static" is required so that there is not
#   // an implicit this pointer added to the prototype by the C++ compiler
#   static int Destroy(void* kimmdl);
#   static int Reinit(void* kimmdl);
#   static int Compute(void* kimmdl);
#
#  private:
#   EAM_Implementation* implementation_;
# };
#
# #endif  // EAM_HPP_

# %% [markdown]
# ## getallfiles()
#
# Downloads all source files associated with a model
#
# __Parameters__
#
# - __kimid__ (*str*) The kim id to access all data for.
#
# - __path__ (*str, optional*) The path to where the downloaded zip file is to be saved.  Default value is 'archive.zip'
#
# __Returns__
#
# - (*zipfile.ZipFile*) The downloaded contents.

# %%
md_files = kimanalysis.getallfiles(md_id)
for md_file in md_files.namelist():
    print(md_file)
md_files.close()
# Out:
# EAM_Dynamo__MD_120291908751_004/
# EAM_Dynamo__MD_120291908751_004/EAM.hpp
# EAM_Dynamo__MD_120291908751_004/EAM_DynamoCubicHermiteSpline.cpp
# EAM_Dynamo__MD_120291908751_004/kimspec.edn
# EAM_Dynamo__MD_120291908751_004/CreateDispatch.sh
# EAM_Dynamo__MD_120291908751_004/EAM.kim.tpl
# EAM_Dynamo__MD_120291908751_004/README
# EAM_Dynamo__MD_120291908751_004/EAM_DynamoCubicHermiteSpline.hpp
# EAM_Dynamo__MD_120291908751_004/EAM_Implementation.cpp
# EAM_Dynamo__MD_120291908751_004/LICENSE.CDDL
# EAM_Dynamo__MD_120291908751_004/EAM_Implementation.hpp
# EAM_Dynamo__MD_120291908751_004/Makefile
# EAM_Dynamo__MD_120291908751_004/kimprovenance.edn
# EAM_Dynamo__MD_120291908751_004/EAM.cpp
